# %%
# !pip install -q kokoro>=0.9.2 soundfile
# !apt-get -qq -y install espeak-ng > /dev/null 2>&1
# Out:
# The system cannot find the path specified.

# %%
from kokoro import KPipeline
from IPython.display import display, Audio
import soundfile as sf
import torch

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
pipeline = KPipeline(lang_code='a' , device=device)
text = '''
Test hello 124g How r u today? This is a text to speech synthesis demo using Kokoro.
'''
generator = pipeline(text, voice='af_heart')
for i, (gs, ps, audio) in enumerate(generator):
    print(i, gs, ps)
    display(Audio(data=audio, rate=24000, autoplay=i==0))
    sf.write(f'{i}.wav', audio, 24000)
# Out:
# WARNING: Defaulting repo_id to hexgrad/Kokoro-82M. Pass repo_id='hexgrad/Kokoro-82M' to suppress this warning.
# 0 Test hello 124g How r u today? This is a text to speech synthesis demo using Kokoro. tˈɛst həlˈO wˈʌn hˈʌndɹəd twˈɛnti fˈɔɹ ʤˈi hˌW ˈɑɹ jˈu tədˈA? ðˌɪs ɪz ɐ tˈɛkst tə spˈiʧ sˈɪnθəsɪs dˈɛmO jˈuzɪŋ kəkˈɔɹO.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
